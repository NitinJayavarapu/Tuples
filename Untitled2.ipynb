# %%
tpl=(10,20,30,40,"Nitin","python")
print(tpl)
# Out:
# (10, 20, 30, 40, 'Nitin', 'python')

# %%
tpl[3]
# Out:
# 40

# %%
tpl[:]
# Out:
# (10, 20, 30, 40, 'Nitin', 'python')

# %%
tpl[1:6:2]
# Out:
# (20, 40, 'python')
